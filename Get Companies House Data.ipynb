# %%
import urllib 

url = "http://download.companieshouse.gov.uk/BasicCompanyDataAsOneFile-2022-02-01.zip"
urllib.request.urlretrieve(url, "/tmp/basiccompanydata.csv.zip")
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[2]: (&#39;/tmp/basiccompanydata.csv.zip&#39;, &lt;http.client.HTTPMessage at 0x7fec2617a2d0&gt;)</div>

# %%
# %sh
unzip /tmp/basiccompanydata.csv.zip
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Archive:  /tmp/basiccompanydata.csv.zip
#   inflating: BasicCompanyDataAsOneFile-2022-02-01.csv
# </div>

# %%
dbutils.fs.mv("file:/databricks/driver/BasicCompanyDataAsOneFile-2022-02-01.csv", "dbfs:/companies/BasicCompanyDataAsOneFile-2022-02-01.csv")
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[5]: True</div>

# %%
# %sh
rm /tmp/basiccompanydata.csv.zip
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>
